# %%
library(jsonlite)     # flexible, robust, high performance tools for working with JSON in R
library(dplyr)        # A fast, consistent tool for working with data frame like objects
library(stringi)      # Character String Processing Facilities
library(ggplot2)      # An Implementation of the Grammar of Graphics
library(downloader)   # Download Files over HTTP and HTTPS
library(lubridate)    # To work with date-times

#install.packages("downloader")

# %%
for(i in 1:11){
    url=paste0("https://download.open.fda.gov/drug/label/drug-label-000",i,"-of-0011.json.zip")
    download(url,dest="json.zip")
    unzip ("json.zip")
}

# https://download.open.fda.gov/drug/label/drug-label-0001-of-0011.json.zip"
# Out:
# Warning message in download.file(url, method = method, ...):
# “cannot open URL 'https://download.open.fda.gov/drug/label/drug-label-00010-of-0011.json.zip': HTTP status was '404 Not Found'”
# Error in download.file(url, method = method, ...): cannot open URL 'https://download.open.fda.gov/drug/label/drug-label-00010-of-0011.json.zip'
# Traceback:
#
# 1. download(url, dest = "json.zip")
# 2. download.file(url, method = method, ...)

# %%
# Create character vector of file names

filenames <- list.files(pattern="*.json", full.names=TRUE)

# %%
drug1 = fromJSON(filenames[1])

names(drug1)
# Out:
# [1] "meta"    "results"

# %%
drug1$meta
# Out:
# $disclaimer
# [1] "Do not rely on openFDA to make decisions regarding medical care. While we make every effort to ensure that data is accurate, you should assume all results are unvalidated. We may limit or otherwise restrict your access to the API in line with our Terms of Service."
#
# $terms
# [1] "https://open.fda.gov/terms/"
#
# $license
# [1] "https://open.fda.gov/license/"
#
# $last_updated
# [1] "2022-11-24"
#
# $results
# $results$skip
# [1] 0
#
# $results$limit
# [1] 20000
#
# $results$total
# [1] 205387

# %%
results=drug1$results
class(results)
# Out:
# [1] "data.frame"

# %%
glimpse(results)
# Out:
# Rows: 20,000
# Columns: 138
# $ spl_product_data_elements                                        <list> "Oxy…
# $ package_label_principal_display_panel                            <list> "Pri…
# $ set_id                                                           <chr> "e65d…
# $ id                                                               <chr> "ee16…
# $ effective_time                                                   <chr> "2022…
# $ version                                                          <chr> "3", …
# $ openfda                                                          <df[,21]> <…
# $ active_ingredient                                                <list> <NUL…
# $ dosage_forms_and_strengths                                       <list> <NUL…
# $ purpose                                                          <list> <NUL…
# $ indications_and_usage                                            <list> <NUL…
# $ warnings                                                         <list> <NUL…
# $ pregnancy_or_breast_feeding                                      <list> <NUL…
# $ ask_doctor                                                       <list> <NUL…
# $ keep_out_of_reach_of_children                                    <list> <NUL…
# $ instructions_for_use                                             <list> <NUL…
# $ dosage_and_administration                                        <list> <NUL…
# $ route                                                            <list> <NUL…
# $ inactive_ingredient                                              <list> <NUL…
# $ questions                                                        <list> <NUL…
# $ spl_unclassified_section                                         <list> <NUL…
# $ do_not_use                                                       <list> <NUL…
# $ when_using                                                       <list> <NUL…
# $ stop_use                                                         <list> <NUL…
# $ storage_and_handling                                             <list> <NUL…
# $ boxed_warning                                                    <list> <NUL…
# $ contraindications                                                <list> <NUL…
# $ warnings_and_cautions                                            <list> <NUL…
# $ adverse_reactions                                                <list> <NUL…
# $ adverse_reactions_table                                          <list> <NUL…
# $ drug_interactions                                                <list> <NUL…
# $ use_in_specific_populations                                      <list> <NUL…
# $ pregnancy                                                        <list> <NUL…
# $ labor_and_delivery                                               <list> <NUL…
# $ pediatric_use                                                    <list> <NUL…
# $ geriatric_use                                                    <list> <NUL…
# $ overdosage                                                       <list> <NUL…
# $ description                                                      <list> <NUL…
# $ clinical_pharmacology                                            <list> <NUL…
# $ mechanism_of_action                                              <list> <NUL…
# $ pharmacodynamics                                                 <list> <NUL…
# $ pharmacokinetics                                                 <list> <NUL…
# $ nonclinical_toxicology                                           <list> <NUL…
# $ carcinogenesis_and_mutagenesis_and_impairment_of_fertility       <list> <NUL…
# $ clinical_studies                                                 <list> <NUL…
# $ how_supplied                                                     <list> <NUL…
# $ information_for_patients                                         <list> <NUL…
# $ spl_patient_package_insert                                       <list> <NUL…
# $ recent_major_changes                                             <list> <NUL…
# $ recent_major_changes_table                                       <list> <NUL…
# $ dosage_and_administration_table                                  <list> <NUL…
# $ drug_interactions_table                                          <list> <NUL…
# $ clinical_pharmacology_table                                      <list> <NUL…
# $ pharmacokinetics_table                                           <list> <NUL…
# $ microbiology                                                     <list> <NUL…
# $ animal_pharmacology_and_or_toxicology                            <list> <NUL…
# $ clinical_studies_table                                           <list> <NUL…
# $ spl_medguide                                                     <list> <NUL…
# $ spl_medguide_table                                               <list> <NUL…
# $ how_supplied_table                                               <list> <NUL…
# $ nursing_mothers                                                  <list> <NUL…
# $ pharmacodynamics_table                                           <list> <NUL…
# $ references                                                       <list> <NUL…
# $ ask_doctor_or_pharmacist                                         <list> <NUL…
# $ active_ingredient_table                                          <list> <NUL…
# $ purpose_table                                                    <list> <NUL…
# $ other_safety_information                                         <list> <NUL…
# $ warnings_and_cautions_table                                      <list> <NUL…
# $ risks                                                            <list> <NUL…
# $ drug_abuse_and_dependence                                        <list> <NUL…
# $ dependence                                                       <list> <NUL…
# $ description_table                                                <list> <NUL…
# $ spl_unclassified_section_table                                   <list> <NUL…
# $ precautions                                                      <list> <NUL…
# $ general_precautions                                              <list> <NUL…
# $ indications_and_usage_table                                      <list> <NUL…
# $ dosage_forms_and_strengths_table                                 <list> <NUL…
# $ spl_patient_package_insert_table                                 <list> <NUL…
# $ microbiology_table                                               <list> <NUL…
# $ laboratory_tests                                                 <list> <NUL…
# $ teratogenic_effects                                              <list> <NUL…
# $ nonteratogenic_effects                                           <list> <NUL…
# $ safe_handling_warning                                            <list> <NUL…
# $ instructions_for_use_table                                       <list> <NUL…
# $ drug_and_or_laboratory_test_interactions                         <list> <NUL…
# $ controlled_substance                                             <list> <NUL…
# $ abuse                                                            <list> <NUL…
# $ package_label_principal_display_panel_table                      <list> <NUL…
# $ use_in_specific_populations_table                                <list> <NUL…
# $ pediatric_use_table                                              <list> <NUL…
# $ precautions_table                                                <list> <NUL…
# $ spl_indexing_data_elements                                       <list> <NUL…
# $ user_safety_warnings                                             <list> <NUL…
# $ geriatric_use_table                                              <list> <NUL…
# $ warnings_table                                                   <list> <NUL…
# $ general_precautions_table                                        <list> <NUL…
# $ summary_of_safety_and_effectiveness                              <list> <NUL…
# $ patient_medication_information                                   <list> <NUL…
# $ pharmacogenomics                                                 <list> <NUL…
# $ drug_and_or_laboratory_test_interactions_table                   <list> <NUL…
# $ information_for_patients_table                                   <list> <NUL…
# $ references_table                                                 <list> <NUL…
# $ mechanism_of_action_table                                        <list> <NUL…
# $ nonclinical_toxicology_table                                     <list> <NUL…
# $ carcinogenesis_and_mutagenesis_and_impairment_of_fertility_table <list> <NUL…
# $ contraindications_table                                          <list> <NUL…
# $ storage_and_handling_table                                       <list> <NUL…
# $ accessories                                                      <list> <NUL…
# $ intended_use_of_the_device                                       <list> <NUL…
# $ components                                                       <list> <NUL…
# $ cleaning                                                         <list> <NUL…
# $ statement_of_identity                                            <list> <NUL…
# $ do_not_use_table                                                 <list> <NUL…
# $ inactive_ingredient_table                                        <list> <NUL…
# $ health_claim                                                     <list> <NUL…
# $ disposal_and_waste_handling                                      <list> <NUL…
# $ questions_table                                                  <list> <NUL…
# $ stop_use_table                                                   <list> <NUL…
# $ information_for_owners_or_caregivers                             <list> <NUL…
# $ overdosage_table                                                 <list> <NUL…
# $ when_using_table                                                 <list> <NUL…
# $ keep_out_of_reach_of_children_table                              <list> <NUL…
# $ patient_medication_information_table                             <list> <NUL…
# $ drug_abuse_and_dependence_table                                  <list> <NUL…
# $ abuse_table                                                      <list> <NUL…
# $ boxed_warning_table                                              <list> <NUL…
# $ health_care_provider_letter                                      <list> <NUL…
# $ health_care_provider_letter_table                                <list> <NUL…
# $ pregnancy_table                                                  <list> <NUL…
# $ ask_doctor_table                                                 <list> <NUL…
# $ pregnancy_or_breast_feeding_table                                <list> <NUL…
# $ ask_doctor_or_pharmacist_table                                   <list> <NUL…
# $ laboratory_tests_table                                           <list> <NUL…
# $ animal_pharmacology_and_or_toxicology_table                      <list> <NUL…
# $ information_for_owners_or_caregivers_table                       <list> <NUL…
# $ troubleshooting                                                  <list> <NUL…
# $ risks_table                                                      <list> <NUL…
# $ veterinary_indications                                           <list> <NUL…

# %%
glimpse(results$openfda)
# Out:
# Rows: 20,000
# Columns: 21
# $ brand_name                    <list> "Oxygen", "Palladium Metallicum", "SPF …
# $ generic_name                  <list> "OXYGEN", "PALLADIUM METALLICUM", "TITA…
# $ manufacturer_name             <list> "Resp-I-Care, Inc.", "Hahnemann Laborat…
# $ product_ndc                   <list> "58125-0001", <"37662-1992", "37662-199…
# $ product_type                  <list> "HUMAN PRESCRIPTION DRUG", "HUMAN OTC D…
# $ route                         <list> "RESPIRATORY (INHALATION)", "ORAL", "TO…
# $ substance_name                <list> "OXYGEN", "PALLADIUM", <"TITANIUM DIOXI…
# $ rxcui                         <list> "312172", <NULL>, <NULL>, <"283316", "2…
# $ spl_id                        <list> "ee16c042-8f88-447d-e053-2995a90aae9a",…
# $ spl_set_id                    <list> "e65d92c1-71db-4a10-83a4-d2556be7559e",…
# $ package_ndc                   <list> <"58125-0001-0", "58125-0001-7", "58125…
# $ is_original_packager          <list> TRUE, TRUE, TRUE, TRUE, TRUE, TRUE, TRU…
# $ unii                          <list> "S88TT14065", "5TWQ1V240M", <"15FIX9V2J…
# $ application_number            <list> <NULL>, <NULL>, "part352", "ANDA208727"…
# $ upc                           <list> <NULL>, <NULL>, "0813277012474", <NULL>…
# $ nui                           <list> <NULL>, <NULL>, <NULL>, <"N0000000070",…
# $ pharm_class_moa               <list> <NULL>, <NULL>, <NULL>, "Angiotensin 2 …
# $ pharm_class_epc               <list> <NULL>, <NULL>, <NULL>, <"Angiotensin 2…
# $ pharm_class_pe                <list> <NULL>, <NULL>, <NULL>, "Increased Diur…
# $ pharm_class_cs                <list> <NULL>, <NULL>, <NULL>, "Thiazides [CS]…
# $ original_packager_product_ndc <list> <NULL>, <NULL>, <NULL>, <NULL>, <NULL>,…

# %%
spl = fromJSON(filenames[1])$results                  # read drug-label-0001-of-0005.json
spl=select(spl,effective_time,boxed_warning)          # select effective_time and boxed_warning

  for(i in 2:length(filenames)){                      # read all the rest
      
      tmp =fromJSON(filenames[i])$results
      
   spl=rbind(spl, select(tmp,effective_time,boxed_warning))  # concatenate all
}

# %%
glimpse(spl)
# Out:
# Rows: 180,000
# Columns: 2
# $ effective_time <chr> "20221122", "20221122", "20210222", "20211013", "202106…
# $ boxed_warning  <list> <NULL>, <NULL>, <NULL>, "WARNING: FETAL TOXICITY When …

# %%
spl=mutate(spl,effective_time=stri_sub(effective_time,1,8))

# %%
spl%>%group_by(nchar(effective_time))%>%summarize(count=n())
# Out:
#   nchar(effective_time) count
# 1 8                     180000

# %%
# Convert characters to date
spl=mutate(spl,effective_time =ymd(effective_time))
# Out:
# Warning message:
# “ 1 failed to parse.”

# %%
glimpse(spl)
# Out:
# Rows: 180,000
# Columns: 2
# $ effective_time <date> 2022-11-22, 2022-11-22, 2021-02-22, 2021-10-13, 2021-0…
# $ boxed_warning  <list> <NULL>, <NULL>, <NULL>, "WARNING: FETAL TOXICITY When …

# %%
spl%>%group_by(effective_time)%>%summarize(Total=n())%>%
ggplot(aes(x=effective_time,y=Total))+geom_line()
# Out:
# Warning message:
# “Removed 1 row containing missing values (`geom_line()`).”
# plot without title

# %%
# Exclude submissions prior to 2009
spl%>%filter(effective_time>ymd("20081231"))%>%
              group_by(effective_time)%>%summarize(Total=n())%>%
ggplot(aes(x=effective_time,y=Total))+geom_line()
# Out:
# plot without title

# %%
spl=mutate(spl, year = format(effective_time, "%Y"))

# %%
spl%>%
    filter(effective_time>ymd("20081231") & effective_time < ymd("20220101"))%>%
    group_by(year)%>%
    summarize(Total=n())%>%
    ggplot(aes(x=year,y=Total, fill=Total))+geom_bar(stat="identity",color='white')+
    ggtitle('Annual drug labeling submissions')+xlab('')+ylab('Total number of submission')
# Out:
# plot without title
